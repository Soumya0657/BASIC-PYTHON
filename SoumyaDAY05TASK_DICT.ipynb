# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumya0657/BASIC-PYTHON/blob/https%2Fmybinder.org%2Fv2%2Fgh%2Fjupyterlab%2Fjupyterlab-demo%2F79184a07d47cf03787b39cfc345da98794d76554urlpath%3Dlab%252Ftree%252Fdemo%252Ftask1ML.ipynb/SoumyaDAY05TASK_DICT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#invert a dictionary
my_map = { 'a': 1, 'b':2 }
dict(map(reversed, my_map.items()))
# Out:
# {1: 'a', 2: 'b'}

# %%
#filter Dictionary Values
dict = {'a':5, 'b':2}
x = 4;
print ([dict[i] for i in dict if dict[i] >= x])
# Out:
# [5]

# %%
#Combine 2 lists to create a dictionary
list1=['a','b','c']
list2=[1,2,3]
dictinary=dict(zip(list1,list2))

# %%
# Count the characters of a string
s = "TECHNICAL OFFICER!"


count = len(s)

print(count)
# Out:
# 18

# %%
# Square the dictionary values
my_dict = {'a': 2, 'b': 3, 'c': 4}


squared_dict = {key: value ** 2 for key, value in my_dict.items()}

print(squared_dict)
# Out:
# {'a': 4, 'b': 9, 'c': 16}

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-e3080359b3fa> in <cell line: 0>()
#       1 #series
#       2 import pandas as pd
# ----> 3 new_series = pd.series([5,6,7,8,9,10] , index=['a','b','c','d','e','f'])
#       4 print(new_series)
#       5 print('___________')
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
#series
import pandas as pd
new_series = pd.Series([5,6,7,8,9,10] , index=['a','b','c','d','e','f']) # Changed 'pd.series' to 'pd.Series'
print(new_series)
print('___________')
new_series[['a','b','f']]=0
print(new_series)
# Out:
# a     5
# b     6
# c     7
# d     8
# e     9
# f    10
# dtype: int64
# ___________
# a    0
# b    0
# c    7
# d    8
# e    9
# f    0
# dtype: int64

# %%
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-85422a4f1d3f> in <cell line: 0>()
# ----> 1 sns.scatterplot(x='Attack', y='Defense', data=df1 , fit_reg=False , hue='Speed') # change 'Stage' to 'stage'
#       2 plt.show()
#       3
#       4
#
# /usr/local/lib/python3.11/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     634     kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
#     635
# --> 636     p.plot(ax, kwargs)
#     637
#     638     return ax
#
# /usr/local/lib/python3.11/dist-packages/seaborn/relational.py in plot(self, ax, kws)
#     436
#     437         # Draw the scatter plot
# --> 438         points = ax.scatter(x=x, y=y, **kws)
#     439
# ...

# %%
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Out:
# <Axes: >

# %%
g=sns.catplot(x='Type 1', y='Attack', data=df1, hue='Speed', col='Speed', kind='swarm') # Replaced 'factoryplot' with 'catplot' and corrected 'swarn' to 'swarm'
g.set_xticklabels(rotation=-45)
plt.show() # Added plt.show() to display the plot
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-e8fb288cb974> in <cell line: 0>()
# ----> 1 g=sns.catplot(x='Type 1', y='Attack', data=df1, hue='Speed', col='Speed', kind='swarm') # Replaced 'factoryplot' with 'catplot' and corrected 'swarn' to 'swarm'
#       2 g.set_xticklabels(rotation=-45)
#       3 plt.show() # Added plt.show() to display the plot
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, seed, units, weights, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2895             plot_kws["linewidth"] = np.sqrt(plot_kws["s"]) / 10
#    2896
# -> 2897         p.plot_swarms(
# ...

# %%
g=sns.catplot(x='Type 1', y='Attack', data=df1, hue='Speed', col='Speed', kind='swarm') # Replaced 'factoryplot' with 'catplot' and corrected 'swarn' to 'swarm'
g.set_xticklabels(rotation=-45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-546419574cf2> in <cell line: 0>()
# ----> 1 g=sns.catplot(x='Type 1', y='Attack', data=df1, hue='Speed', col='Speed', kind='swarm') # Replaced 'factoryplot' with 'catplot' and corrected 'swarn' to 'swarm'
#       2 g.set_xticklabels(rotation=-45)
#       3 plt.show()
#
# NameError: name 'sns' is not defined
